# %% [markdown]
# <img src="https://github.com/christopherhuntley/BUAN5405-docs/blob/master/Slides/img/Dolan.png?raw=true" width="180px" align="right">
#
# # Lesson 13: Final Project
# _A beginning to end programming assignment_

# %% [markdown]
# _Please follow the directions given below, which step through an analysis of timestamped historical data. Points will be awarded as indicated. Note: later steps depend on earlier steps, so you should check your work as you go along._
#
# You may use whatever documentation you like (even Google) but you may not consult anyone else. That includes sharing code with your classmates, which is obviously not allowed.
#
# __Finally, use comments to document what you are doing with each block of code. Poorly documented code will be penalized accordingly.__

# %% [markdown]
# ## Imports
# Import pandas in the usual way. You may use other modules if you like, but please also import them here so we know what you're trying to do.

# %% [markdown]
# ## 1. (3 points) Analyze the Source Data
# Open the [AAPL_MSFT_IBM.csv](https://raw.githubusercontent.com/christopherhuntley/BUAN5405-lessons/master/AAPL_MSFT_IBM.csv) file in GitHub. Study the data for structure and purpose. What is the purpose of the first row? What do the columns represent? What data type is each column?

# %% [markdown]
# YOUR ANSWER TO QUESTION 1 HERE.

# %% [markdown]
# ## 2. (10 points) Load the source data.
# Use the pandas [read_csv()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) function to load the data `AAPL_MSFT_IBM.csv` as follows:
# * Three DataFrames named `aapl`, `msft`, and `ibm`.
# * Each dataframe should have the following columns: `date`,`high`,`low`,`close`,`volume`
# * Use the dates as the index.
# * Date strings should be parsed as pandas datetime objects.
#
# Do not alter the data file. You must read it as given.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 3. (5 points) Plot the closing prices over time.
# * For full credit, plot each separately using the `plot()` method. For another 5 points extra credit, plot all three tickers on the same plot.
# * Label the y axis as `Price per Share`.
# * Display a legend that labels each series with its ticker symbol.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 4. (6 points) Add a "fluctuation" column to `aapl`, `msft`, and `ibm`.
# Daily fluctuation percentage is 100*(high-low)/close.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 5. (5 points) Plot the fluctations over time for each stock.
# Use the same technique as you used in step 3.

# %% [markdown]
# ## 6. (5 points) Use `argmax` to determine the date of the largest fluctation in `aapl` price. How big was the fluctuation that day?
# What was so special about that particular day? Answer in a _new_ markdown cell below your code.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 7. (6 points) Calculate the correlation between "fluctuation" and "volume" for `aapl`. Then display a scatter plot.
# Does there appear to be a correlation? Comment on the correlation with a _new_ markdown cell below your code.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 8. (10 points) Fully comment your code.
# It should be clear that you understand exactly what each line of code does. If calling functions or methods, indicate why did you set any named arguments.  If setting a variable then say what purpose the variable serves, etc. Every decision you made should be documented.

# %% [markdown]
# ## Save and sync your work to GitHub.

# %%
# Connect with Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Sync to GitHub
github_email = "" #@param {type:"string"}
github_username = "" #@param {type:"string"}
repo_name = "buan5405-lessons-USERNAME" #@param {type:"string"}
commit_comment = "Completed Lesson 13" #@param {type:"string"}

if github_email and github_username and repo_name and commit_comment :  
  repo_dir = "/content/drive/My Drive/Colab Notebooks/"+repo_name
  # %cd {repo_dir}
  # !git config --global user.email {github_email}
  # !git config --global user.name {github_username}
  # !git add .
  # !git commit -m "{commit_comment}"
  # !git push
else:
  print("Please fill out all fields")

# %% [markdown]
# ## Pledge your work.
# Type your name in the cell below this to agree with the following:
# > On my honor as a Fairfield University student, I have neither given nor received any unauthorized aid on this project.

# %% [markdown]
# YOUR NAME HERE
