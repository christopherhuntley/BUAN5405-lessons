# %% [markdown]
# <img src="https://github.com/christopherhuntley/BUAN5405-docs/blob/master/Slides/img/Dolan.png?raw=true" width="180px" align="right">
#
# # Lesson 13: Final Project
# _Putting it all together into one assignment_

# %% [markdown]
# _Please follow the directions given below, which step through an analysis of timestamped historical data. Points will be awarded as indicated. Note: later requirements depend on earlier requirements, so you should check your work as you go along._
#
# You may use whatever documentation you like (even Google) but you may not consult anyone else. That includes sharing code with your classmates, which is obviously not allowed.
#
# ---
# # Requirements / Grading Criteria
# Please structure your work as a report below this cell. Try to be as polished and professional as you can be.
#
# Required elements are outlined below.
#
# 1. **(3 points) Analyze the Source Data.**
# Open the [AAPL_MSFT_IBM](https://raw.githubusercontent.com/christopherhuntley/BUAN5405-lessons/master/AAPL_MSFT_IBM.csv) file in GitHub. Study the data for structure and purpose. What is the purpose of the first row? What do the columns represent? What data type is each column?
# Include a markdown cell with your comments.
#
# 2. **(10 points) Load the source data.**
# Use the pandas `read_csv()` function to load the the `AAPL_MSFT_IBM.csv` dataset from GitHub as follows:
#
#   - Three DataFrames named `aapl`, `msft`, and `ibm`.
#   - Each dataframe should have the following columns: `date`,`high`,`low`,`close`,`volume`
#   - Use the dates as the index.
#   - Date strings should be parsed as pandas datetime objects.
#   - Do not alter the data file. You must read it as given.
#
# 3. **(5 points) Plot the closing prices over time.**
#   - For full credit, plot each separately using the plot() method.
#   - For _another 5 points extra credit_, plot all three tickers on the same plot.
#   - Label the y axis as `Price per Share`.
#   - Display a legend that labels each series with its ticker symbol.
#
# 4. **(6 points) Add a "fluctuation" column to `aapl`, `msft`, and `ibm`.**
#   Daily fluctuation percentage is 100*(high-low)/close.
#
# 5. **(5 points) Plot the fluctations over time for each stock.**.
# Use the same technique as you used in requirement 3.
#
# 6. **(5 points) Use `argmax` to determine the date of the largest fluctation in `aapl` price.**
#   - How big was the fluctuation that day?
#   - What was so special about that particular day?
#   - Be sure to clearly answer both questions
#
# 7. **(6 points) Calculate the correlation between "fluctuation" and "volume" for `aapl`. Then display a scatter plot.**
#   - Does there appear to be a correlation?
#   - Again, include your analysis in the report.
#
# 8. **(10 points) Document everything like a pro with appropriate markdown and code comments.**
#   - **Comments** should explain exactly what each line of code does, If calling functions or methods, indicate why did you set any named arguments.  If setting a variable then say what purpose the variable serves, etc. Every decision you made should be documented.
#   - **Markdown** is used to structure your document so it can be read and understood by other humans. Use section headings, not just bolded text. Use bullet points, not big blocks of text. Frame your analysis so that we get exactly what you concluded _and why_.
#
# 9. **(15 points) Prepare a 10 minute YouTube video walking us through your code.**
#   - Keep it brief and focused on your code.
#   - No slides, just your notebook and a voiceover. Zoom or QuickTime can be used to do that.
#   - Do not try to sell anything. The idea is to solicit constructive feedback, not convince us of anything.
#   - On August 13, post a link to the video in the class slack channel. **Do not post before August 13.**
#
# 10. **(10 points) Reviews your peers' work.**
# You will be assigned two of your peers' walkthrough videos to watch and fill out a review form. Reviews will be due by the end of August 14. Be as professional and honest as you can in your criticism. _You are being graded on your assessments. If they differ substantially from the instructor's then you will lose all credit for your reviews._
# ---

# %% [markdown]
# # **YOUR WORK GOES HERE.**

# %% [markdown]
# ---
# ## Pledge your work.
# Type your name in the cell below this to agree with the following:
# > On my honor as a Fairfield University student, I have neither given nor received any unauthorized aid on this project.

# %% [markdown]
# **YOUR NAME HERE**

# %% [markdown]
# ---
# ## **Before you go ... Submit your work on Google Classroom**
# - Save your notebook to be sure it is up to date.
# - Go to the assignment in Google Classroom.
# - Turn in your notebook. You notebook will become read-only.
# - Once it has been reviewed it will be returned and no-longer be read-only.
